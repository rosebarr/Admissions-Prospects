# %%
from google.colab import drive   # I import files from Google Drive to Google colab
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd   #import pandas

# %%
path="/content/drive/MyDrive/google colab/Student Performance Data (2).csv"

# %%
df = pd.read_csv(path)

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#      math score  reading score  writing score  total score  \
# 0            72             72             74          218
# ...

# %% [markdown]
# 1.

# %%
df.groupby(["parental level of education"]).mean()
# Out:
# <ipython-input-28-fcbbee2846a9>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(["parental level of education"]).mean()
#                              math score  reading score  writing score  \
# parental level of education
# associate's degree            67.882883      70.927928      69.896396
# bachelor's degree             69.389831      73.000000      73.381356
# high school                   62.137755      64.704082      62.448980
# master's degree               69.745763      75.372881      75.677966
# some college                  67.128319      69.460177      68.840708
# some high school              63.497207      66.938547      64.888268
#
#                              total score
# parental level of education
# associate's degree            208.707207
# ...

# %%
df.groupby(["parental level of education"]).median()
# Out:
# <ipython-input-15-dc6bff934c1b>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(["parental level of education"]).median()
#                              math score  reading score  writing score  \
# parental level of education
# associate's degree                 67.0           72.5           70.5
# bachelor's degree                  68.0           73.0           74.0
# high school                        63.0           66.0           64.0
# master's degree                    73.0           76.0           75.0
# some college                       67.5           70.5           70.0
# some high school                   65.0           67.0           66.0
#
#                              total score
# parental level of education
# associate's degree                 209.0
# ...

# %% [markdown]
# 2. Which group performs best as classified as an admissions prospect?

# %%
df.groupby(["race/ethnicity"]).mean()
# Out:
# <ipython-input-37-26949321910d>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(["race/ethnicity"]).mean()
#                 math score  reading score  writing score  total score
# race/ethnicity
# group A          61.629213      64.674157      62.674157   188.977528
# group B          63.452632      67.352632      65.600000   196.405263
# group C          64.463950      69.103448      67.827586   201.394984
# group D          67.362595      70.030534      70.145038   207.538168
# group E          73.821429      73.028571      71.407143   218.257143

# %%
df.groupby(["race/ethnicity","admission prospect"]).mean()
# Out:
# <ipython-input-38-b586db502d52>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(["race/ethnicity","admission prospect"]).mean()
#                                    math score  reading score  writing score  \
# race/ethnicity admission prospect
# group A        high                 79.142857      85.952381      83.428571
#                low                  47.740741      48.592593      46.185185
#                medium               61.804878      64.365854      62.902439
# group B        high                 78.377049      83.803279      81.950820
#                low                  43.800000      46.300000      43.525000
#                medium               62.056180      65.539326      64.314607
# group C        high                 78.826923      83.211538      83.067308
# ...

# %% [markdown]
# 3.	How does each gender perform in total score categorized by test preparation course completed or not?

# %%
df.groupby(["gender"]).count()
# Out:
#         race/ethnicity  parental level of education  lunch  math score  \
# gender
# female             518                          518    518         518
# male               482                          482    482         482
#
#         reading score  writing score  total score  test preparation course  \
# gender
# female            518            518          518                      518
# male              482            482          482                      482
#
#         admission prospect
# gender
# female                 518
# male                   482

# %%
df.groupby(["gender"]).mean()
# Out:
# <ipython-input-33-96c2206b9888>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(["gender"]).mean()
#         math score  reading score  writing score  total score
# gender
# female   63.633205      72.608108      72.467181   208.708494
# male     68.728216      65.473029      63.311203   197.512448

# %%
df.groupby(["gender","test preparation course"]).mean()
# Out:
# <ipython-input-34-3b7d84a86c67>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(["gender","test preparation course"]).mean()
#                                 math score  reading score  writing score  \
# gender test preparation course
# female completed                 67.195652      77.375000      78.793478
#        none                      61.670659      69.982036      68.982036
# male   completed                 72.339080      70.212644      69.793103
#        none                      66.688312      62.795455      59.649351
#
#                                 total score
# gender test preparation course
# female completed                 223.364130
#        none                      200.634731
# male   completed                 212.344828
# ...

# %%
df.groupby(["gender", "test preparation course"]).mean()[["total score"]]
# Out:
# <ipython-input-32-24a6cf0a5b9c>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(["gender", "test preparation course"]).mean()[["total score"]]
#                                 total score
# gender test preparation course
# female completed                 223.364130
#        none                      200.634731
# male   completed                 212.344828
#        none                      189.133117

# %% [markdown]
# 4. Are there differences between race/ethnicity? Explain your analysis

# %%
df.groupby(["race/ethnicity"]).count()
# Out:
#                 gender  parental level of education  lunch  math score  \
# race/ethnicity
# group A             89                           89     89          89
# group B            190                          190    190         190
# group C            319                          319    319         319
# group D            262                          262    262         262
# group E            140                          140    140         140
#
#                 reading score  writing score  total score  \
# race/ethnicity
# group A                    89             89           89
# group B                   190            190          190
# group C                   319            319          319
# group D                   262            262          262
# group E                   140            140          140
#
#                 test preparation course  admission prospect
# race/ethnicity
# group A                              89                  89
# ...

# %%
df.groupby(["race/ethnicity"]).mean()
# Out:
# <ipython-input-27-26949321910d>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(["race/ethnicity"]).mean()
#                 math score  reading score  writing score  total score
# race/ethnicity
# group A          61.629213      64.674157      62.674157   188.977528
# group B          63.452632      67.352632      65.600000   196.405263
# group C          64.463950      69.103448      67.827586   201.394984
# group D          67.362595      70.030534      70.145038   207.538168
# group E          73.821429      73.028571      71.407143   218.257143

# %%
df.groupby(["race/ethnicity"]).count() [["total score"]]
# Out:
#                 total score
# race/ethnicity
# group A                  89
# group B                 190
# group C                 319
# group D                 262
# group E                 140

# %%
df.groupby(["test preparation course","admission prospect"]).mean()
# Out:
# <ipython-input-26-54c58c9bb351>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(["test preparation course","admission prospect"]).mean()
#                                             math score  reading score  \
# test preparation course admission prospect
# completed               high                 79.714286      84.247253
#                         low                  44.866667      48.166667
#                         medium               62.308219      66.273973
# none                    high                 80.522989      82.994253
#                         low                  45.517986      48.251799
#                         medium               63.221884      65.553191
#
#                                             writing score  total score
# ...

# %%
df.groupby(["race/ethnicity","lunch"]).mean() [["total score"]]
# Out:
# <ipython-input-9-d370ee06425a>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(["race/ethnicity","lunch"]).mean() [["total score"]]
#                              total score
# race/ethnicity lunch
# group A        free/reduced   172.972222
#                standard       199.849057
# group B        free/reduced   182.927536
#                standard       204.090909
# group C        free/reduced   181.236842
#                standard       212.604878
# group D        free/reduced   194.000000
#                standard       215.239521
# group E        free/reduced   202.487805
#                standard       224.787879

# %% [markdown]
# 5. Is the sample biased?  Explain your analysis.

# %%
df.groupby(["gender"]).count()
